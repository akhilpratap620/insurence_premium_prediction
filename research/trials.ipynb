# %%
2*2

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import os
os.getcwd()
os.chdir('../')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\somit\\Downloads\\project_ineuron\\insurence_premium_prediction'

# %%
df=pd.read_csv(r'artifacts\data_ingestion\train\insurence.csv' ,index_col='Unnamed: 0')

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1069.000000  1069.000000  1069.000000   1069.000000
# mean     39.291862    30.631618     1.113190  13329.626520
# std      13.993944     6.201512     1.213726  12115.458852
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      26.000000    26.100000     0.000000   4719.740000
# 50%      40.000000    30.200000     1.000000   9386.160000
# 75%      51.000000    34.500000     2.000000  17128.430000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
import seaborn as sns

# %%
df_cat=[column for column in df.columns if df[column].dtypes=='O']

# %%
df_num =[column for column in df.columns if df[column].dtypes!='O']

# %%
sns.barplot(x=df['sex'] ,y=df['expenses'] ,hue=df[''])
# Out:
# <Axes: xlabel='sex', ylabel='expenses'>

# %%
sns.barplot(x=df['sex'] ,y=df['expenses'] ,hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='expenses'>

# %%
for column in df.columns:
    if df[column].dtypes!='O':

        sns.histplot(df[column] ,kde=True,color='red')
        plt.show()

# %%
df.corr()
# Out:
# C:\Users\somit\AppData\Local\Temp\ipykernel_5056\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       bmi  children  expenses
# age       1.000000  0.105026  0.050920  0.300586
# bmi       0.105026  1.000000  0.029566  0.190916
# children  0.050920  0.029566  1.000000  0.081076
# expenses  0.300586  0.190916  0.081076  1.000000

# %%
for column in df.columns:
    if df[column].dtypes!='O':

        sns.boxplot(df[column] ,color='blue' ,)
        plt.title(f"{column}")
        plt.show()

# %% [markdown]
# In independent feature we don't have too much outlier
# but still we have outlier in bmi feature but not too much
# so we can keep and because if we remove outlier in the bmi feature
# so we loose some data(that is important for dependent feature)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1069.000000  1069.000000  1069.000000   1069.000000
# mean     39.291862    30.631618     1.113190  13329.626520
# std      13.993944     6.201512     1.213726  12115.458852
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      26.000000    26.100000     0.000000   4719.740000
# 50%      40.000000    30.200000     1.000000   9386.160000
# 75%      51.000000    34.500000     2.000000  17128.430000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# if we see in bmi section standard deviation is 6

# %%
for column in df.columns:
    
    if df[column].dtypes != 'O':

        sns.distplot(df[column])
        plt.show()
# Out:
# C:\Users\somit\AppData\Local\Temp\ipykernel_5056\3360665600.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\somit\AppData\Local\Temp\ipykernel_5056\3360665600.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# ...

# %%
sns.pairplot(df)

# %%
sns.lineplot(df.drop(columns=['expenses']))
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
print(f"male in the dateset:{len(df[df['sex']=='male'])}")

print(f"female in the dateset:{len(df[df['sex']=='female'])}")
# Out:
# male in the dateset:553
# female in the dateset:516

# %%
print(f"smoker in the dateset:{len(df[df['smoker']=='yes'])}")

print(f"non smoker in the dateset:{len(df[df['smoker']=='no'])}")
# Out:
# smoker in the dateset:220
# non smoker in the dateset:849

# %% [markdown]
# male and female in data not too much difference alomost equal

# %%
sns.barplot(x=df['sex'] ,y=df['expenses'] ,hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='expenses'>

# %% [markdown]
# smoker expense is very high than non smoker either male or female

# %%
sns.barplot(x=df['smoker'] ,y=df['expenses'] ,hue=df['sex'])
# Out:
# <Axes: xlabel='smoker', ylabel='expenses'>

# %% [markdown]
# we can see clearly defference smoker expense is very high
